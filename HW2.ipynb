# %%
import pandas as pd
import numpy as np
import wbgapi as wb
import yfinance as yf

import statsmodels.api as sm
from statsmodels.formula.api import ols, logit

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Question 1
#
# For this question use the World Bank Data for Turkey for the following indicators. Use [wbgapi](https://pypi.org/project/wbgapi/) for getting the data.
#
# * [Literacy rate, adult female (SE.ADT.LITR.FE.ZS)](https://data.worldbank.org/indicator/SE.ADT.LITR.FE.ZS)
# * [Labor force, female (SL.TLF.TOTL.FE.ZS)](https://data.worldbank.org/indicator/SL.TLF.TOTL.FE.ZS)
# * [Poverty headcount ratio at national poverty lines (SI.POV.NAHC)](https://data.worldbank.org/indicator/SI.POV.NAHC)
# * [Current health expenditure per capita (SH.XPD.CHEX.PC.CD)](https://data.worldbank.org/indicator/SH.XPD.CHEX.PC.CD)
# * [GDP per capita (NY.GDP.PCAP.CD)](https://data.worldbank.org/indicator/NY.GDP.PCAP.CD)
# * [Mortality rate, under-5 (SH.DYN.MORT)](https://data.worldbank.org/indicator/SH.DYN.MORT)
#
#
# Using the [statsmodels](https://www.statsmodels.org/stable/index.html) library write the best linear regression model using child mortality as the dependent variable while the rest are considered as independent variables. Pay particular attention to the fact that the order of the variables put into the model significantly impacts the performance of the model. Choose the best model by considering
#
# * with the minimum number of variables and their interactions,
# * with the optimal ordering of the independent variables and their interactions,
# * $R^2$-score of the model,
# * statistical significance of the model coefficients,
# * ANOVA analysis of the model.

# %% [markdown]
# ## Answers for Q1
#
# You can download more than one series specific to a country as follows:

# %%
data = wb.data.DataFrame(series = ['SE.ADT.LITR.FE.ZS','SL.TLF.TOTL.FE.ZS','SI.POV.NAHC',
                                   'SH.XPD.CHEX.PC.CD','NY.GDP.PCAP.CD','SH.DYN.MORT'],
                         economy='TUR').T
data.rename(columns={'SE.ADT.LITR.FE.ZS':'literacy',
                     'SL.TLF.TOTL.FE.ZS':'labor',
                     'SI.POV.NAHC':'poverty',
                     'SH.XPD.CHEX.PC.CD':'expenditure',
                     'NY.GDP.PCAP.CD':'gdp',
                     'SH.DYN.MORT':'mortality'}, inplace=True)
data.dropna(inplace=True)
data
# Out:
# series           gdp   literacy  mortality  expenditure  poverty      labor
# YR2005   7456.296101  80.548950       26.2   364.908051     18.6  25.921956
# YR2006   8101.856924  80.385162       24.3   416.928528     16.3  26.205298
# YR2007   9791.882450  81.263832       22.5   512.848267     16.7  26.288681
# YR2009   9103.474051  85.347160       19.5   500.193054     16.9  28.071295
# YR2010  10742.774979  88.073174       18.1   539.327148     16.1  29.161917
# YR2011  11420.555456  90.310097       16.9   531.418579     16.3  29.832127
# YR2012  11795.633457  91.604523       15.8   524.250305     15.0  30.464131
# YR2013  12614.781610  92.138077       14.7   551.401245     15.0  31.199391
# YR2014  12157.990434  92.401817       13.8   525.844727     14.7  31.027784
# YR2015  11006.279524  92.645813       13.0   453.116486     14.3  31.719798
# YR2016  10894.603378  93.563011       12.1   466.794800     13.5  32.250459
# YR2017  10589.667725  93.498268       11.4   442.617615     13.9  32.799757
# YR2019   9121.515167  94.424042       10.1   396.466827     15.0  33.360649

# %% [markdown]
# The first thing you must do before you do a linear regression problem is to check if independent variables are correlated. Because high correlation among the independent variables degredates the quality of the resulting model.

# %%
data.corr()
# Out:
# series            gdp  literacy  mortality  expenditure   poverty     labor
# series
# gdp          1.000000  0.708098  -0.624924     0.786933 -0.642485  0.591484
# literacy     0.708098  1.000000  -0.976415     0.240982 -0.849316  0.981657
# mortality   -0.624924 -0.976415   1.000000    -0.173542  0.885762 -0.989861
# expenditure  0.786933  0.240982  -0.173542     1.000000 -0.192544  0.097192
# poverty     -0.642485 -0.849316   0.885762    -0.192544  1.000000 -0.867518
# labor        0.591484  0.981657  -0.989861     0.097192 -0.867518  1.000000

# %% [markdown]
# Female labor partipication, female literacy rate and child mortality are highly correlated. Since our dependent variable is mortality, it is better if dropped one of literacy or labor participation. I'll keep labor partipation.

# %%
model = ols('mortality ~  poverty + expenditure + labor + gdp', data=data).fit()
model.summary()
# Out:
# /home/kaygun/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1477: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              mortality   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.988
# Method:                 Least Squares   F-statistic:                     242.2
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           2.23e-08
# Time:                        20:27:44   Log-Likelihood:                -7.8525
# No. Observations:                  13   AIC:                             25.70
# Df Residuals:                       8   BIC:                             28.53
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      70.1838      7.670      9.151      0.000      52.497      87.870
# poverty         0.4428      0.249      1.777      0.113      -0.132       1.017
# expenditure    -0.0185      0.007     -2.783      0.024      -0.034      -0.003
# labor          -1.9570      0.146    -13.445      0.000      -2.293      -1.621
# gdp             0.0007      0.000      2.092      0.070   -6.96e-05       0.001
# ==============================================================================
# Omnibus:                        1.741   Durbin-Watson:                   2.147
# Prob(Omnibus):                  0.419   Jarque-Bera (JB):                1.157
# Skew:                          -0.484   Prob(JB):                        0.561
# Kurtosis:                       1.905   Cond. No.                     5.14e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.14e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Among the model coefficients only expenditure and labor are significant. But before we settle on our model, let us check the ANOVA table:

# %%
sm.stats.anova_lm(model)
# Out:
#               df      sum_sq     mean_sq           F        PR(>F)
# poverty      1.0  244.065138  244.065138  766.422629  3.126859e-09
# expenditure  1.0    0.002896    0.002896    0.009093  9.263777e-01
# labor        1.0   63.070572   63.070572  198.056610  6.311465e-07
# gdp          1.0    1.393817    1.393817    4.376917  6.978890e-02
# Residual     8.0    2.547578    0.318447         NaN           NaN

# %% [markdown]
# It seems poverty seems to be important along with labor. But recall that the ordering of the varibles is also important:

# %%
model = ols('mortality ~ labor + poverty', data=data).fit()
print(model.summary())
sm.stats.anova_lm(model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              mortality   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     285.4
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           1.51e-09
# Time:                        20:27:44   Log-Likelihood:                -12.683
# No. Observations:                  13   AIC:                             31.37
# Df Residuals:                      10   BIC:                             33.06
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     63.7616      9.301      6.855      0.000      43.037      84.486
# labor         -1.7773      0.166    -10.729      0.000      -2.146      -1.408
# poverty        0.3935      0.300      1.310      0.219      -0.276       1.063
# ==============================================================================
# Omnibus:                        0.080   Durbin-Watson:                   1.269
# Prob(Omnibus):                  0.961   Jarque-Bera (JB):                0.283
# Skew:                          -0.120   Prob(JB):                        0.868
# Kurtosis:                       2.318   Cond. No.                     1.55e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.55e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /home/kaygun/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1477: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#             df      sum_sq     mean_sq           F        PR(>F)
# labor      1.0  304.804040  304.804040  569.016826  3.808848e-10
# poverty    1.0    0.919281    0.919281    1.716140  2.194839e-01
# Residual  10.0    5.356679    0.535668         NaN           NaN

# %% [markdown]
# The coefficent of the poverty variable still isn't significant. Moreover, when we changed the order, the contribution of the variable poverty to the variance has dropped significantly. So, one variable seems to enough:

# %%
model = ols('mortality ~ labor', data=data).fit()
print(model.summary())
sm.stats.anova_lm(model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              mortality   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.978
# Method:                 Least Squares   F-statistic:                     534.2
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           1.13e-10
# Time:                        20:27:44   Log-Likelihood:                -13.713
# No. Observations:                  13   AIC:                             31.43
# Df Residuals:                      11   BIC:                             32.56
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     75.5089      2.549     29.627      0.000      69.899      81.118
# labor         -1.9655      0.085    -23.114      0.000      -2.153      -1.778
# ==============================================================================
# Omnibus:                        2.355   Durbin-Watson:                   1.193
# Prob(Omnibus):                  0.308   Jarque-Bera (JB):                0.478
# Skew:                           0.293   Prob(JB):                        0.787
# Kurtosis:                       3.734   Cond. No.                         365.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /home/kaygun/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1477: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#             df     sum_sq     mean_sq           F        PR(>F)
# labor      1.0  304.80404  304.804040  534.236098  1.126086e-10
# Residual  11.0    6.27596    0.570542         NaN           NaN

# %% [markdown]
# Our analysis indicates that as the female participation to the labor force increases the child mortality drops. In other words, the more women work outside of the homes, the lesser the child mortality. Also, female literacy rate and female labor participation are highly correlated. The analysis does not indicate a cause-effect relationship between literacy rates and labor participation for women. But whichever is the driver, both have a negative relationship with child mortality. The more women learn reading and writing and work outside homes, the lesser the child mortality rates.

# %% [markdown]
# # Question 2
#
# For this question use Yahoo's Finance API for the following tickers:
#
# * Gold futures (GC=F)
# * Silver futures (SI=F)
# * Copper futures (HG=F)
# * Platinum futures (PL=F)
#
# 1. Write the best linear regression model that explains gold futures closing prices in terms of opening prices of gold, silver, copper, and platinum futures.
# 2. Repeat the same for silver, copper and platinum prices.
# 3. Compare the models you obtained in Steps 1 and 2. Which model is better? How do you decide? Explain.

# %% [markdown]
# ## Answers for Q2

# %%
futures = yf.download(['GC=F','SI=F','HG=F','PL=F'])
futures
# Out:
# [*********************100%***********************]  4 of 4 completed
#               Adj Close                                        Close          \
#                    GC=F    HG=F         PL=F       SI=F         GC=F    HG=F
# Date
# 2000-01-04          NaN     NaN   429.700012        NaN          NaN     NaN
# 2000-01-05          NaN     NaN   419.899994        NaN          NaN     NaN
# 2000-01-06          NaN     NaN   412.000000        NaN          NaN     NaN
# 2000-01-07          NaN     NaN   414.000000        NaN          NaN     NaN
# 2000-01-10          NaN     NaN   415.000000        NaN          NaN     NaN
# ...                 ...     ...          ...        ...          ...     ...
# 2022-11-11  1766.000000  3.9510  1047.400024  21.646000  1766.000000  3.9510
# 2022-11-14  1773.599976  3.8550  1042.300049  22.091999  1773.599976  3.8550
# 2022-11-15  1773.800049  3.8395  1031.699951  21.499001  1773.800049  3.8395
# 2022-11-16  1773.000000  3.7880  1025.500000  21.504000  1773.000000  3.7880
# 2022-11-17  1760.400024  3.6840   987.700012  20.940001  1760.400024  3.6840
#
#                                            High          ...          Low  \
#                    PL=F       SI=F         GC=F    HG=F  ...         PL=F
# Date                                                     ...
# 2000-01-04   429.700012        NaN          NaN     NaN  ...   421.000000
# 2000-01-05   419.899994        NaN          NaN     NaN  ...   416.899994
# 2000-01-06   412.000000        NaN          NaN     NaN  ...   409.000000
# 2000-01-07   414.000000        NaN          NaN     NaN  ...   408.000000
# 2000-01-10   415.000000        NaN          NaN     NaN  ...   414.000000
# ...                 ...        ...          ...     ...  ...          ...
# 2022-11-11  1047.400024  21.646000  1766.000000  3.9510  ...  1047.400024
# 2022-11-14  1042.300049  22.091999  1773.599976  3.8720  ...  1042.300049
# 2022-11-15  1031.699951  21.499001  1773.800049  3.8505  ...  1031.699951
# 2022-11-16  1025.500000  21.504000  1778.900024  3.7880  ...  1025.500000
# 2022-11-17   987.700012  20.940001  1777.599976  3.7725  ...   985.000000
#
#                               Open                                   Volume  \
#                  SI=F         GC=F   HG=F         PL=F       SI=F      GC=F
# Date
# 2000-01-04        NaN          NaN    NaN   428.000000        NaN       NaN
# 2000-01-05        NaN          NaN    NaN   428.000000        NaN       NaN
# 2000-01-06        NaN          NaN    NaN   415.000000        NaN       NaN
# 2000-01-07        NaN          NaN    NaN   408.000000        NaN       NaN
# 2000-01-10        NaN          NaN    NaN   414.000000        NaN       NaN
# ...               ...          ...    ...          ...        ...       ...
# 2022-11-11  21.514999  1763.800049  3.917  1047.400024  21.584999     257.0
# 2022-11-14  21.855000  1762.000000  3.848  1042.300049  21.865000     358.0
# 2022-11-15  21.450001  1770.800049  3.849  1031.699951  22.030001      57.0
# 2022-11-16  21.504000  1776.599976  3.788  1025.500000  21.625000      57.0
# 2022-11-17  20.785000  1777.000000  3.761  1016.000000  21.504999  141461.0
#
#
#                HG=F     PL=F     SI=F
# Date
# 2000-01-04      NaN    632.0      NaN
# 2000-01-05      NaN    571.0      NaN
# 2000-01-06      NaN    494.0      NaN
# 2000-01-07      NaN    130.0      NaN
# 2000-01-10      NaN     24.0      NaN
# ...             ...      ...      ...
# 2022-11-11    260.0      1.0     71.0
# 2022-11-14    661.0      1.0     13.0
# 2022-11-15    409.0      1.0     32.0
# 2022-11-16    409.0      1.0     32.0
# 2022-11-17  46793.0  15974.0  54903.0
#
# [5750 rows x 24 columns]

# %%
data = futures[['Open','Close']].dropna()
data
# Out:
#                    Open                                       Close          \
#                    GC=F   HG=F         PL=F       SI=F         GC=F    HG=F
# Date
# 2000-08-30   273.899994  0.879   593.900024   4.950000   273.899994  0.8850
# 2000-08-31   274.799988  0.885   589.000000   4.920000   278.299988  0.8850
# 2000-09-01   277.000000  0.878   588.000000   5.035000   277.000000  0.8890
# 2000-09-05   275.799988  0.896   602.000000   4.990000   275.799988  0.9060
# 2000-09-06   274.200012  0.905   603.000000   5.000000   274.200012  0.9015
# ...                 ...    ...          ...        ...          ...     ...
# 2022-11-11  1763.800049  3.917  1047.400024  21.584999  1766.000000  3.9510
# 2022-11-14  1762.000000  3.848  1042.300049  21.865000  1773.599976  3.8550
# 2022-11-15  1770.800049  3.849  1031.699951  22.030001  1773.800049  3.8395
# 2022-11-16  1776.599976  3.788  1025.500000  21.625000  1773.000000  3.7880
# 2022-11-17  1777.000000  3.761  1016.000000  21.504999  1760.400024  3.6840
#
#
#                    PL=F       SI=F
# Date
# 2000-08-30   591.400024   4.930000
# 2000-08-31   586.700012   5.003000
# 2000-09-01   595.299988   5.004000
# 2000-09-05   601.299988   4.998000
# 2000-09-06   611.099976   4.983000
# ...                 ...        ...
# 2022-11-11  1047.400024  21.646000
# 2022-11-14  1042.300049  22.091999
# 2022-11-15  1031.699951  21.499001
# 2022-11-16  1025.500000  21.504000
# 2022-11-17   987.700012  20.940001
#
# [4873 rows x 8 columns]

# %%
data.columns = ['gold_open','copper_open','platinum_open','silver_open',
                'gold_close','copper_close','platinum_close','silver_close']
data
# Out:
#               gold_open  copper_open  platinum_open  silver_open   gold_close  \
# Date
# 2000-08-30   273.899994        0.879     593.900024     4.950000   273.899994
# 2000-08-31   274.799988        0.885     589.000000     4.920000   278.299988
# 2000-09-01   277.000000        0.878     588.000000     5.035000   277.000000
# 2000-09-05   275.799988        0.896     602.000000     4.990000   275.799988
# 2000-09-06   274.200012        0.905     603.000000     5.000000   274.200012
# ...                 ...          ...            ...          ...          ...
# 2022-11-11  1763.800049        3.917    1047.400024    21.584999  1766.000000
# 2022-11-14  1762.000000        3.848    1042.300049    21.865000  1773.599976
# 2022-11-15  1770.800049        3.849    1031.699951    22.030001  1773.800049
# 2022-11-16  1776.599976        3.788    1025.500000    21.625000  1773.000000
# 2022-11-17  1777.000000        3.761    1016.000000    21.504999  1760.400024
#
#             copper_close  platinum_close  silver_close
# Date
# 2000-08-30        0.8850      591.400024      4.930000
# 2000-08-31        0.8850      586.700012      5.003000
# 2000-09-01        0.8890      595.299988      5.004000
# 2000-09-05        0.9060      601.299988      4.998000
# 2000-09-06        0.9015      611.099976      4.983000
# ...                  ...             ...           ...
# 2022-11-11        3.9510     1047.400024     21.646000
# 2022-11-14        3.8550     1042.300049     22.091999
# 2022-11-15        3.8395     1031.699951     21.499001
# 2022-11-16        3.7880     1025.500000     21.504000
# 2022-11-17        3.6840      987.700012     20.940001
#
# [4873 rows x 8 columns]

# %%
data.corr()
# Out:
#                 gold_open  copper_open  platinum_open  silver_open  \
# gold_open        1.000000     0.830371       0.500505     0.869802
# copper_open      0.830371     1.000000       0.743147     0.854540
# platinum_open    0.500505     0.743147       1.000000     0.760726
# silver_open      0.869802     0.854540       0.760726     1.000000
# gold_close       0.999758     0.830407       0.500397     0.869586
# copper_close     0.829660     0.999411       0.743056     0.853605
# platinum_close   0.499915     0.742731       0.999707     0.760366
# silver_close     0.869478     0.854649       0.761109     0.999327
#
#                 gold_close  copper_close  platinum_close  silver_close
# gold_open         0.999758      0.829660        0.499915      0.869478
# copper_open       0.830407      0.999411        0.742731      0.854649
# platinum_open     0.500397      0.743056        0.999707      0.761109
# silver_open       0.869586      0.853605        0.760366      0.999327
# gold_close        1.000000      0.829864        0.499939      0.869739
# copper_close      0.829864      1.000000        0.742788      0.854082
# platinum_close    0.499939      0.742788        1.000000      0.760897
# silver_close      0.869739      0.854082        0.760897      1.000000

# %% [markdown]
# Gold futures closing price is highly correlated with its opening price. Silver and copper opening prices also show high correlation with gold futures closing price. However, it also seems that platinum opening prices are not strongly related with gold futures closing prices. Let us write our model.

# %%
model = ols('gold_close ~ gold_open + copper_open + silver_open + platinum_open', data=data).fit()
print(model.summary())
sm.stats.anova_lm(model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             gold_close   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.516e+06
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):               0.00
# Time:                        20:27:45   Log-Likelihood:                -18767.
# No. Observations:                4873   AIC:                         3.754e+04
# Df Residuals:                    4868   BIC:                         3.758e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.4537      0.661      0.687      0.492      -0.841       1.749
# gold_open         0.9988      0.001   1104.176      0.000       0.997       1.001
# copper_open       0.6432      0.360      1.789      0.074      -0.062       1.348
# silver_open       0.0016      0.059      0.026      0.979      -0.114       0.117
# platinum_open    -0.0008      0.001     -0.888      0.375      -0.003       0.001
# ==============================================================================
# Omnibus:                     1501.085   Durbin-Watson:                   2.062
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            29940.316
# Skew:                          -0.972   Prob(JB):                         0.00
# Kurtosis:                      14.987   Cond. No.                     6.73e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.73e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                    df        sum_sq       mean_sq             F    PR(>F)
# gold_open         1.0  1.305421e+09  1.305421e+09  1.006293e+07  0.000000
# copper_open       1.0  2.358927e+02  2.358927e+02  1.818396e+00  0.177567
# silver_open       1.0  7.869381e+01  7.869381e+01  6.066171e-01  0.436102
# platinum_open     1.0  1.023025e+02  1.023025e+02  7.886063e-01  0.374566
# Residual       4868.0  6.315046e+05  1.297257e+02           NaN       NaN

# %% [markdown]
# ANOVA analysis seem to indicate opening prices for gold futures is enough for model building.

# %%
model = ols('gold_close ~ gold_open', data=data).fit()
print(model.summary())
sm.stats.anova_lm(model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             gold_close   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.006e+07
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):               0.00
# Time:                        20:27:45   Log-Likelihood:                -18768.
# No. Observations:                4873   AIC:                         3.754e+04
# Df Residuals:                    4871   BIC:                         3.755e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3047      0.388      0.785      0.433      -0.456       1.066
# gold_open      0.9996      0.000   3172.143      0.000       0.999       1.000
# ==============================================================================
# Omnibus:                     1522.512   Durbin-Watson:                   2.061
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30215.728
# Skew:                          -0.994   Prob(JB):                         0.00
# Kurtosis:                      15.036   Cond. No.                     2.93e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.93e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                df        sum_sq       mean_sq             F  PR(>F)
# gold_open     1.0  1.305421e+09  1.305421e+09  1.006249e+07     0.0
# Residual   4871.0  6.319214e+05  1.297314e+02           NaN     NaN

# %% [markdown]
# Let us repeat this for other futures. Let us start with silver and write the largest model possible with all interactions.

# %%
model = ols('silver_close ~ silver_open * gold_open * platinum_open * copper_open', data=data).fit()
print(model.summary())
sm.stats.anova_lm(model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           silver_close   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 2.448e+05
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):               0.00
# Time:                        20:27:46   Log-Likelihood:                -1276.9
# No. Observations:                4873   AIC:                             2586.
# Df Residuals:                    4857   BIC:                             2690.
# Df Model:                          15
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          -0.3857      0.200     -1.930      0.054      -0.777       0.006
# silver_open                                         1.0912      0.060     18.293      0.000       0.974       1.208
# gold_open                                          -0.0005      0.000     -1.202      0.230      -0.001       0.000
# silver_open:gold_open                            -4.41e-06   3.66e-05     -0.120      0.904   -7.63e-05    6.74e-05
# platinum_open                                       0.0004      0.000      1.308      0.191      -0.000       0.001
# silver_open:platinum_open                          -0.0001    6.3e-05     -1.891      0.059      -0.000    4.39e-06
# gold_open:platinum_open                           7.17e-07   4.48e-07      1.599      0.110   -1.62e-07     1.6e-06
# silver_open:gold_open:platinum_open              1.338e-08   3.43e-08      0.390      0.696   -5.38e-08    8.06e-08
# copper_open                                         0.4253      0.161      2.642      0.008       0.110       0.741
# silver_open:copper_open                            -0.0334      0.017     -2.018      0.044      -0.066      -0.001
# gold_open:copper_open                              -0.0002      0.000     -0.951      0.342      -0.000       0.000
# silver_open:gold_open:copper_open                6.861e-06   1.04e-05      0.661      0.509   -1.35e-05    2.72e-05
# platinum_open:copper_open                          -0.0003      0.000     -3.327      0.001      -0.001      -0.000
# silver_open:platinum_open:copper_open            3.387e-05   1.49e-05      2.278      0.023    4.72e-06     6.3e-05
# gold_open:platinum_open:copper_open              1.369e-07    1.4e-07      0.975      0.330   -1.38e-07    4.12e-07
# silver_open:gold_open:platinum_open:copper_open -8.606e-09   8.45e-09     -1.018      0.309   -2.52e-08    7.97e-09
# ==============================================================================
# Omnibus:                     3382.070   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           383134.425
# Skew:                          -2.468   Prob(JB):                         0.00
# Kurtosis:                      46.158   Cond. No.                     7.15e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.15e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                                      df         sum_sq  \
# silver_open                                         1.0  364233.242791
# gold_open                                           1.0       0.102638
# silver_open:gold_open                               1.0       0.612727
# platinum_open                                       1.0       0.711787
# silver_open:platinum_open                           1.0       0.890857
# gold_open:platinum_open                             1.0       0.372490
# silver_open:gold_open:platinum_open                 1.0       0.004975
# copper_open                                         1.0       0.600271
# silver_open:copper_open                             1.0       0.550935
# gold_open:copper_open                               1.0       1.317554
# silver_open:gold_open:copper_open                   1.0       0.012795
# platinum_open:copper_open                           1.0       0.142438
# silver_open:platinum_open:copper_open               1.0       3.481540
# gold_open:platinum_open:copper_open                 1.0       0.112947
# silver_open:gold_open:platinum_open:copper_open     1.0       0.102820
# Residual                                         4857.0     481.866246
#
#                                                        mean_sq             F  \
# silver_open                                      364233.242791  3.671311e+06
# gold_open                                             0.102638  1.034542e+00
# silver_open:gold_open                                 0.612727  6.176016e+00
# platinum_open                                         0.711787  7.174501e+00
# silver_open:platinum_open                             0.890857  8.979445e+00
# gold_open:platinum_open                               0.372490  3.754534e+00
# silver_open:gold_open:platinum_open                   0.004975  5.014306e-02
# copper_open                                           0.600271  6.050465e+00
# silver_open:copper_open                               0.550935  5.553183e+00
# gold_open:copper_open                                 1.317554  1.328037e+01
# silver_open:gold_open:copper_open                     0.012795  1.289704e-01
# platinum_open:copper_open                             0.142438  1.435714e+00
# silver_open:platinum_open:copper_open                 3.481540  3.509239e+01
# gold_open:platinum_open:copper_open                   0.112947  1.138457e+00
# silver_open:gold_open:platinum_open:copper_open       0.102820  1.036378e+00
# Residual                                              0.099211           NaN
#
#                                                        PR(>F)
# silver_open                                      0.000000e+00
# gold_open                                        3.091449e-01
# silver_open:gold_open                            1.298276e-02
# platinum_open                                    7.419605e-03
# silver_open:platinum_open                        2.744139e-03
# gold_open:platinum_open                          5.272237e-02
# silver_open:gold_open:platinum_open              8.228239e-01
# copper_open                                      1.393723e-02
# silver_open:copper_open                          1.848660e-02
# gold_open:copper_open                            2.710028e-04
# silver_open:gold_open:copper_open                7.195176e-01
# platinum_open:copper_open                        2.308926e-01
# silver_open:platinum_open:copper_open            3.360947e-09
# gold_open:platinum_open:copper_open              2.860316e-01
# silver_open:gold_open:platinum_open:copper_open  3.087160e-01
# Residual                                                  NaN

# %% [markdown]
# As before, the opening prices were enough.

# %%
model = ols('silver_close ~ silver_open', data=data).fit()
print(model.summary())
sm.stats.anova_lm(model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           silver_close   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 3.614e+06
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):               0.00
# Time:                        20:27:46   Log-Likelihood:                -1322.1
# No. Observations:                4873   AIC:                             2648.
# Df Residuals:                    4871   BIC:                             2661.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0200      0.010      2.007      0.045       0.000       0.039
# silver_open     0.9984      0.001   1901.121      0.000       0.997       0.999
# ==============================================================================
# Omnibus:                     3675.858   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           472266.564
# Skew:                          -2.798   Prob(JB):                         0.00
# Kurtosis:                      50.902   Cond. No.                         41.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                  df         sum_sq        mean_sq             F  PR(>F)
# silver_open     1.0  364233.242791  364233.242791  3.614263e+06     0.0
# Residual     4871.0     490.883018       0.100777           NaN     NaN

# %% [markdown]
# Next, copper prices:

# %%
model = ols('copper_close ~ copper_open * gold_open * platinum_open * silver_open', data=data).fit()
print(model.summary())
sm.stats.anova_lm(model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           copper_close   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 2.762e+05
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):               0.00
# Time:                        20:27:46   Log-Likelihood:                 9011.9
# No. Observations:                4873   AIC:                        -1.799e+04
# Df Residuals:                    4857   BIC:                        -1.789e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                           0.0095      0.024      0.393      0.694      -0.038       0.057
# copper_open                                         0.9926      0.019     50.919      0.000       0.954       1.031
# gold_open                                        9.977e-05   5.27e-05      1.895      0.058   -3.45e-06       0.000
# copper_open:gold_open                             -2.8e-05   2.01e-05     -1.395      0.163   -6.73e-05    1.13e-05
# platinum_open                                    7.627e-06   3.28e-05      0.232      0.816   -5.68e-05     7.2e-05
# copper_open:platinum_open                       -1.193e-06   1.26e-05     -0.095      0.925   -2.59e-05    2.35e-05
# gold_open:platinum_open                         -1.523e-07   5.43e-08     -2.805      0.005   -2.59e-07   -4.59e-08
# copper_open:gold_open:platinum_open              4.108e-08    1.7e-08      2.416      0.016    7.75e-09    7.44e-08
# silver_open                                        -0.0135      0.007     -1.871      0.061      -0.028       0.001
# copper_open:silver_open                             0.0036      0.002      1.773      0.076      -0.000       0.007
# gold_open:silver_open                            6.655e-06   4.44e-06      1.500      0.134   -2.04e-06    1.54e-05
# copper_open:gold_open:silver_open               -1.486e-06   1.26e-06     -1.182      0.237   -3.95e-06    9.79e-07
# platinum_open:silver_open                        1.669e-05   7.63e-06      2.187      0.029    1.73e-06    3.16e-05
# copper_open:platinum_open:silver_open           -4.075e-06    1.8e-06     -2.264      0.024    -7.6e-06   -5.46e-07
# gold_open:platinum_open:silver_open             -6.497e-09   4.15e-09     -1.565      0.118   -1.46e-08    1.64e-09
# copper_open:gold_open:platinum_open:silver_open  1.399e-09   1.02e-09      1.367      0.172   -6.08e-10    3.41e-09
# ==============================================================================
# Omnibus:                      874.115   Durbin-Watson:                   2.145
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17199.700
# Skew:                           0.269   Prob(JB):                         0.00
# Kurtosis:                      12.188   Cond. No.                     7.15e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.15e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                                      df       sum_sq  \
# copper_open                                         1.0  6023.636556
# gold_open                                           1.0     0.000955
# copper_open:gold_open                               1.0     0.005391
# platinum_open                                       1.0     0.000234
# copper_open:platinum_open                           1.0     0.007688
# gold_open:platinum_open                             1.0     0.011402
# copper_open:gold_open:platinum_open                 1.0     0.000644
# silver_open                                         1.0     0.000910
# copper_open:silver_open                             1.0     0.005315
# gold_open:silver_open                               1.0     0.000055
# copper_open:gold_open:silver_open                   1.0     0.000131
# platinum_open:silver_open                           1.0     0.001230
# copper_open:platinum_open:silver_open               1.0     0.007015
# gold_open:platinum_open:silver_open                 1.0     0.000875
# copper_open:gold_open:platinum_open:silver_open     1.0     0.002716
# Residual                                         4857.0     7.063060
#
#                                                      mean_sq             F  \
# copper_open                                      6023.636556  4.142227e+06
# gold_open                                           0.000955  6.566493e-01
# copper_open:gold_open                               0.005391  3.706893e+00
# platinum_open                                       0.000234  1.612334e-01
# copper_open:platinum_open                           0.007688  5.286683e+00
# gold_open:platinum_open                             0.011402  7.841041e+00
# copper_open:gold_open:platinum_open                 0.000644  4.431435e-01
# silver_open                                         0.000910  6.259947e-01
# copper_open:silver_open                             0.005315  3.654887e+00
# gold_open:silver_open                               0.000055  3.788117e-02
# copper_open:gold_open:silver_open                   0.000131  8.974797e-02
# platinum_open:silver_open                           0.001230  8.460021e-01
# copper_open:platinum_open:silver_open               0.007015  4.824029e+00
# gold_open:platinum_open:silver_open                 0.000875  6.014768e-01
# copper_open:gold_open:platinum_open:silver_open     0.002716  1.867452e+00
# Residual                                            0.001454           NaN
#
#                                                    PR(>F)
# copper_open                                      0.000000
# gold_open                                        0.417785
# copper_open:gold_open                            0.054246
# platinum_open                                    0.688041
# copper_open:platinum_open                        0.021531
# gold_open:platinum_open                          0.005128
# copper_open:gold_open:platinum_open              0.505641
# silver_open                                      0.428867
# copper_open:silver_open                          0.055964
# gold_open:silver_open                            0.845690
# copper_open:gold_open:silver_open                0.764511
# platinum_open:silver_open                        0.357731
# copper_open:platinum_open:silver_open            0.028113
# gold_open:platinum_open:silver_open              0.438053
# copper_open:gold_open:platinum_open:silver_open  0.171830
# Residual                                              NaN

# %%
model = ols('copper_close ~ copper_open', data=data).fit()
print(model.summary())
sm.stats.anova_lm(model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           copper_close   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 4.128e+06
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):               0.00
# Time:                        20:27:46   Log-Likelihood:                 8996.6
# No. Observations:                4873   AIC:                        -1.799e+04
# Df Residuals:                    4871   BIC:                        -1.798e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0024      0.001      1.661      0.097      -0.000       0.005
# copper_open     0.9995      0.000   2031.778      0.000       0.999       1.000
# ==============================================================================
# Omnibus:                      883.655   Durbin-Watson:                   2.143
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17217.494
# Skew:                           0.292   Prob(JB):                         0.00
# Kurtosis:                      12.190   Cond. No.                         8.28
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                  df       sum_sq      mean_sq             F  PR(>F)
# copper_open     1.0  6023.636556  6023.636556  4.128123e+06     0.0
# Residual     4871.0     7.107622     0.001459           NaN     NaN

# %% [markdown]
# And finally for platinum prices:

# %%
model = ols('platinum_close ~ platinum_open * gold_open * copper_open * silver_open', data=data).fit()
print(model.summary())
sm.stats.anova_lm(model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         platinum_close   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 5.590e+05
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):               0.00
# Time:                        20:27:46   Log-Likelihood:                -17514.
# No. Observations:                4873   AIC:                         3.506e+04
# Df Residuals:                    4857   BIC:                         3.516e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                           5.4063      5.594      0.966      0.334      -5.561      16.374
# platinum_open                                       0.9990      0.008    131.537      0.000       0.984       1.014
# gold_open                                           0.0336      0.012      2.763      0.006       0.010       0.058
# platinum_open:gold_open                         -3.353e-05   1.26e-05     -2.670      0.008   -5.81e-05   -8.91e-06
# copper_open                                        -8.2381      4.508     -1.828      0.068     -17.075       0.599
# platinum_open:copper_open                           0.0040      0.003      1.367      0.172      -0.002       0.010
# gold_open:copper_open                              -0.0076      0.005     -1.647      0.100      -0.017       0.001
# platinum_open:gold_open:copper_open              6.506e-06   3.93e-06      1.655      0.098    -1.2e-06    1.42e-05
# silver_open                                        -2.9367      1.670     -1.758      0.079      -6.211       0.337
# platinum_open:silver_open                           0.0028      0.002      1.583      0.114      -0.001       0.006
# gold_open:silver_open                               0.0003      0.001      0.304      0.761      -0.002       0.002
# platinum_open:gold_open:silver_open              -3.53e-07    9.6e-07     -0.368      0.713   -2.23e-06    1.53e-06
# copper_open:silver_open                             1.3083      0.463      2.825      0.005       0.400       2.216
# platinum_open:copper_open:silver_open              -0.0009      0.000     -2.135      0.033      -0.002   -7.27e-05
# gold_open:copper_open:silver_open                  -0.0002      0.000     -0.667      0.505      -0.001       0.000
# platinum_open:gold_open:copper_open:silver_open  1.136e-07   2.37e-07      0.480      0.631    -3.5e-07    5.78e-07
# ==============================================================================
# Omnibus:                     2543.950   Durbin-Watson:                   1.917
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           351451.748
# Skew:                          -1.472   Prob(JB):                         0.00
# Kurtosis:                      44.500   Cond. No.                     7.15e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.15e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                                      df        sum_sq  \
# platinum_open                                       1.0  6.519600e+08
# gold_open                                           1.0  1.713511e+02
# platinum_open:gold_open                             1.0  1.309275e+02
# copper_open                                         1.0  1.390985e-01
# platinum_open:copper_open                           1.0  1.307907e+02
# gold_open:copper_open                               1.0  3.259275e+01
# platinum_open:gold_open:copper_open                 1.0  6.734063e+01
# silver_open                                         1.0  1.839719e+03
# platinum_open:silver_open                           1.0  1.620135e+02
# gold_open:silver_open                               1.0  1.526192e+02
# platinum_open:gold_open:silver_open                 1.0  2.086463e-01
# copper_open:silver_open                             1.0  1.627562e+02
# platinum_open:copper_open:silver_open               1.0  1.164537e+03
# gold_open:copper_open:silver_open                   1.0  2.721316e+01
# platinum_open:gold_open:copper_open:silver_open     1.0  1.791221e+01
# Residual                                         4857.0  3.776559e+05
#
#                                                       mean_sq             F  \
# platinum_open                                    6.519600e+08  8.384801e+06
# gold_open                                        1.713511e+02  2.203732e+00
# platinum_open:gold_open                          1.309275e+02  1.683848e+00
# copper_open                                      1.390985e-01  1.788934e-03
# platinum_open:copper_open                        1.307907e+02  1.682087e+00
# gold_open:copper_open                            3.259275e+01  4.191725e-01
# platinum_open:gold_open:copper_open              6.734063e+01  8.660619e-01
# silver_open                                      1.839719e+03  2.366046e+01
# platinum_open:silver_open                        1.620135e+02  2.083641e+00
# gold_open:silver_open                            1.526192e+02  1.962822e+00
# platinum_open:gold_open:silver_open              2.086463e-01  2.683382e-03
# copper_open:silver_open                          1.627562e+02  2.093193e+00
# platinum_open:copper_open:silver_open            1.164537e+03  1.497701e+01
# gold_open:copper_open:silver_open                2.721316e+01  3.499861e-01
# platinum_open:gold_open:copper_open:silver_open  1.791221e+01  2.303674e-01
# Residual                                         7.775498e+01           NaN
#
#                                                    PR(>F)
# platinum_open                                    0.000000
# gold_open                                        0.137742
# platinum_open:gold_open                          0.194476
# copper_open                                      0.966265
# platinum_open:copper_open                        0.194709
# gold_open:copper_open                            0.517381
# platinum_open:gold_open:copper_open              0.352094
# silver_open                                      0.000001
# platinum_open:silver_open                        0.148949
# gold_open:silver_open                            0.161276
# platinum_open:gold_open:silver_open              0.958689
# copper_open:silver_open                          0.148021
# platinum_open:copper_open:silver_open            0.000110
# gold_open:copper_open:silver_open                0.554149
# platinum_open:gold_open:copper_open:silver_open  0.631273
# Residual                                              NaN

# %%
model = ols('platinum_close ~ platinum_open + gold_open + silver_open', data=data).fit()
print(model.summary())
sm.stats.anova_lm(model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         platinum_close   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 2.774e+06
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):               0.00
# Time:                        20:27:46   Log-Likelihood:                -17538.
# No. Observations:                4873   AIC:                         3.508e+04
# Df Residuals:                    4869   BIC:                         3.511e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.8189      0.505      1.621      0.105      -0.172       1.809
# platinum_open     0.9997      0.001   1617.559      0.000       0.998       1.001
# gold_open        -0.0011      0.001     -1.926      0.054      -0.002    1.98e-05
# silver_open       0.0630      0.046      1.376      0.169      -0.027       0.153
# ==============================================================================
# Omnibus:                     2704.000   Durbin-Watson:                   1.919
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           436525.926
# Skew:                          -1.599   Prob(JB):                         0.00
# Kurtosis:                      49.257   Cond. No.                     6.59e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.59e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                    df        sum_sq       mean_sq             F    PR(>F)
# platinum_open     1.0  6.519600e+08  6.519600e+08  8.323082e+06  0.000000
# gold_open         1.0  1.713511e+02  1.713511e+02  2.187510e+00  0.139199
# silver_open       1.0  1.483157e+02  1.483157e+02  1.893434e+00  0.168878
# Residual       4869.0  3.813964e+05  7.833156e+01           NaN       NaN

# %% [markdown]
# # Question 3
#
# 1. Write a function that takes a ticker symbol and returns a pandas dataframe that for each day puts a 1 when the closing price is higher than the opening price, a 0 when the closing price is lower than the opening price.
# 2. Write the best logistic regression that predicts the time series you obtain from Step 1 for gold futures against the opening prices of gold, silver, copper, and platinum prices.
# 3. Repeat the same for silver, copper, and platinum prices.
# 4. Compare the models you obtained from Steps 2 and 3. Decide which is the best model, and explain your reasoning.
# 5. Does any of the models provide a good fit? Explain.

# %%
def isClosingHiger(ticker):
    tmp = yf.download(ticker)[['Open','Close']]
    fn = {True: 1, False: 0}
    return (tmp ['Close'] >= tmp['Open']).replace({False: 0, True: 1})

# %%
data['gold'] = isClosingHiger('GC=F')
data['silver'] = isClosingHiger('SI=F')
data['platinum'] = isClosingHiger('PL=F')
data['copper'] = isClosingHiger('HG=F')
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#               gold_open  copper_open  platinum_open  silver_open   gold_close  \
# Date
# 2000-08-30   273.899994        0.879     593.900024     4.950000   273.899994
# 2000-08-31   274.799988        0.885     589.000000     4.920000   278.299988
# 2000-09-01   277.000000        0.878     588.000000     5.035000   277.000000
# 2000-09-05   275.799988        0.896     602.000000     4.990000   275.799988
# 2000-09-06   274.200012        0.905     603.000000     5.000000   274.200012
# ...                 ...          ...            ...          ...          ...
# 2022-11-11  1763.800049        3.917    1047.400024    21.584999  1766.000000
# 2022-11-14  1762.000000        3.848    1042.300049    21.865000  1773.599976
# 2022-11-15  1770.800049        3.849    1031.699951    22.030001  1773.800049
# 2022-11-16  1776.599976        3.788    1025.500000    21.625000  1773.000000
# 2022-11-17  1777.000000        3.761    1016.000000    21.504999  1760.400024
#
#             copper_close  platinum_close  silver_close  gold  silver  \
# Date
# 2000-08-30        0.8850      591.400024      4.930000     1       0
# 2000-08-31        0.8850      586.700012      5.003000     1       1
# 2000-09-01        0.8890      595.299988      5.004000     1       0
# 2000-09-05        0.9060      601.299988      4.998000     1       1
# 2000-09-06        0.9015      611.099976      4.983000     1       0
# ...                  ...             ...           ...   ...     ...
# 2022-11-11        3.9510     1047.400024     21.646000     1       1
# 2022-11-14        3.8550     1042.300049     22.091999     1       1
# 2022-11-15        3.8395     1031.699951     21.499001     1       0
# 2022-11-16        3.7880     1025.500000     21.504000     0       0
# 2022-11-17        3.6840      987.700012     20.940001     0       0
#
#             platinum  copper
# Date
# 2000-08-30         0       1
# 2000-08-31         0       1
# 2000-09-01         1       1
# 2000-09-05         0       1
# 2000-09-06         1       0
# ...              ...     ...
# 2022-11-11         1       1
# 2022-11-14         1       1
# 2022-11-15         1       0
# 2022-11-16         1       1
# 2022-11-17         0       0
#
# [4873 rows x 12 columns]

# %%
model = logit("gold ~ gold_open * silver_open * copper_open * platinum_open", data=data).fit()
print(model.summary())
y_pred = model.predict(data)
confusion_matrix(data.gold,y_pred > 0.5)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.658416
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   gold   No. Observations:                 4873
# Model:                          Logit   Df Residuals:                     4857
# Method:                           MLE   Df Model:                           15
# Date:                Thu, 17 Nov 2022   Pseudo R-squ.:                 0.02426
# Time:                        20:29:22   Log-Likelihood:                -3208.5
# converged:                       True   LL-Null:                       -3288.2
# Covariance Type:            nonrobust   LLR p-value:                 3.069e-26
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                           7.7547      1.354      5.727      0.000       5.101      10.409
# gold_open                                          -0.0058      0.003     -2.060      0.039      -0.011      -0.000
# silver_open                                        -1.6518      0.394     -4.194      0.000      -2.424      -0.880
# gold_open:silver_open                               0.0013      0.000      5.325      0.000       0.001       0.002
# copper_open                                         0.1022      1.070      0.096      0.924      -1.995       2.199
# gold_open:copper_open                               0.0007      0.001      0.616      0.538      -0.001       0.003
# silver_open:copper_open                             0.3084      0.110      2.801      0.005       0.093       0.524
# gold_open:silver_open:copper_open                  -0.0003   6.85e-05     -4.126      0.000      -0.000      -0.000
# platinum_open                                      -0.0062      0.002     -3.304      0.001      -0.010      -0.003
# gold_open:platinum_open                         -8.512e-07   2.94e-06     -0.289      0.772   -6.62e-06    4.92e-06
# silver_open:platinum_open                           0.0019      0.000      4.560      0.000       0.001       0.003
# gold_open:silver_open:platinum_open               -1.2e-06   2.28e-07     -5.265      0.000   -1.65e-06   -7.53e-07
# copper_open:platinum_open                          -0.0002      0.001     -0.271      0.787      -0.002       0.001
# gold_open:copper_open:platinum_open              1.152e-06   9.13e-07      1.262      0.207   -6.38e-07    2.94e-06
# silver_open:copper_open:platinum_open              -0.0004   9.89e-05     -3.979      0.000      -0.001      -0.000
# gold_open:silver_open:copper_open:platinum_open  2.595e-07    5.6e-08      4.637      0.000     1.5e-07    3.69e-07
# ===================================================================================================================
# array([[ 305, 1666],
#        [ 326, 2576]])

# %%
model = logit("silver ~ gold_open * silver_open * copper_open * platinum_open", data=data).fit()
print(model.summary())
y_pred = model.predict(data)
confusion_matrix(data.silver,y_pred > 0.5)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.625962
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 silver   No. Observations:                 4873
# Model:                          Logit   Df Residuals:                     4857
# Method:                           MLE   Df Model:                           15
# Date:                Thu, 17 Nov 2022   Pseudo R-squ.:                 0.03058
# Time:                        20:29:36   Log-Likelihood:                -3050.3
# converged:                       True   LL-Null:                       -3146.5
# Covariance Type:            nonrobust   LLR p-value:                 7.239e-33
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                           4.5675      1.394      3.277      0.001       1.836       7.300
# gold_open                                          -0.0034      0.003     -1.141      0.254      -0.009       0.002
# silver_open                                        -1.0603      0.404     -2.622      0.009      -1.853      -0.268
# gold_open:silver_open                               0.0007      0.000      2.862      0.004       0.000       0.001
# copper_open                                         2.1070      1.145      1.840      0.066      -0.137       4.351
# gold_open:copper_open                              -0.0008      0.001     -0.736      0.462      -0.003       0.001
# silver_open:copper_open                             0.0872      0.114      0.764      0.445      -0.136       0.311
# gold_open:silver_open:copper_open               -9.418e-05      7e-05     -1.345      0.178      -0.000     4.3e-05
# platinum_open                                      -0.0030      0.002     -1.513      0.130      -0.007       0.001
# gold_open:platinum_open                          3.962e-06   3.05e-06      1.298      0.194   -2.02e-06    9.94e-06
# silver_open:platinum_open                           0.0008      0.000      1.821      0.069   -5.93e-05       0.002
# gold_open:silver_open:platinum_open             -5.974e-07   2.32e-07     -2.580      0.010   -1.05e-06   -1.44e-07
# copper_open:platinum_open                          -0.0010      0.001     -1.438      0.150      -0.002       0.000
# gold_open:copper_open:platinum_open              2.678e-07   9.44e-07      0.284      0.777   -1.58e-06    2.12e-06
# silver_open:copper_open:platinum_open              -0.0001      0.000     -1.060      0.289      -0.000    9.06e-05
# gold_open:silver_open:copper_open:platinum_open  1.023e-07   5.67e-08      1.803      0.071   -8.88e-09    2.14e-07
# ===================================================================================================================
# array([[  92, 1600],
#        [  91, 3090]])

# %%
model = logit("copper ~ gold_open * silver_open * copper_open * platinum_open", data=data).fit()
print(model.summary())
y_pred = model.predict(data)
confusion_matrix(data.copper,y_pred > 0.5)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.685082
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 copper   No. Observations:                 4873
# Model:                          Logit   Df Residuals:                     4857
# Method:                           MLE   Df Model:                           15
# Date:                Thu, 17 Nov 2022   Pseudo R-squ.:                0.005700
# Time:                        20:29:48   Log-Likelihood:                -3338.4
# converged:                       True   LL-Null:                       -3357.5
# Covariance Type:            nonrobust   LLR p-value:                 0.0008216
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                           0.1859      1.284      0.145      0.885      -2.331       2.703
# gold_open                                           0.0024      0.003      0.857      0.391      -0.003       0.008
# silver_open                                        -0.7854      0.384     -2.048      0.041      -1.537      -0.034
# gold_open:silver_open                               0.0005      0.000      1.937      0.053   -5.41e-06       0.001
# copper_open                                         1.4905      1.037      1.437      0.151      -0.542       3.523
# gold_open:copper_open                              -0.0016      0.001     -1.512      0.131      -0.004       0.000
# silver_open:copper_open                             0.1035      0.106      0.973      0.330      -0.105       0.312
# gold_open:silver_open:copper_open               -5.983e-05   6.67e-05     -0.898      0.369      -0.000    7.08e-05
# platinum_open                                       0.0014      0.002      0.788      0.431      -0.002       0.005
# gold_open:platinum_open                         -3.823e-06   2.88e-06     -1.326      0.185   -9.48e-06    1.83e-06
# silver_open:platinum_open                           0.0007      0.000      1.815      0.070   -5.89e-05       0.002
# gold_open:silver_open:platinum_open             -3.862e-07    2.2e-07     -1.754      0.079   -8.18e-07    4.54e-08
# copper_open:platinum_open                          -0.0016      0.001     -2.347      0.019      -0.003      -0.000
# gold_open:copper_open:platinum_open              1.872e-06   9.03e-07      2.074      0.038    1.03e-07    3.64e-06
# silver_open:copper_open:platinum_open              -0.0001   9.56e-05     -1.231      0.218      -0.000    6.97e-05
# gold_open:silver_open:copper_open:platinum_open  5.428e-08   5.43e-08      0.999      0.318   -5.22e-08    1.61e-07
# ===================================================================================================================
# array([[ 283, 1932],
#        [ 252, 2406]])

# %%
model = logit("platinum ~ gold_open * silver_open * copper_open * platinum_open", data=data).fit()
print(model.summary())
y_pred = model.predict(data)
confusion_matrix(data.platinum,y_pred > 0.5)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.502040
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               platinum   No. Observations:                 4873
# Model:                          Logit   Df Residuals:                     4857
# Method:                           MLE   Df Model:                           15
# Date:                Thu, 17 Nov 2022   Pseudo R-squ.:                 0.06351
# Time:                        20:29:58   Log-Likelihood:                -2446.4
# converged:                       True   LL-Null:                       -2612.3
# Covariance Type:            nonrobust   LLR p-value:                 1.326e-61
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                           3.6203      1.580      2.291      0.022       0.524       6.717
# gold_open                                           0.0069      0.004      1.791      0.073      -0.001       0.014
# silver_open                                        -1.0546      0.512     -2.061      0.039      -2.057      -0.052
# gold_open:silver_open                               0.0004      0.000      1.319      0.187      -0.000       0.001
# copper_open                                        -1.5935      1.233     -1.292      0.196      -4.010       0.823
# gold_open:copper_open                              -0.0010      0.001     -0.697      0.486      -0.004       0.002
# silver_open:copper_open                             0.3400      0.133      2.555      0.011       0.079       0.601
# gold_open:silver_open:copper_open                  -0.0002   8.41e-05     -1.854      0.064      -0.000    8.89e-06
# platinum_open                                      -0.0037      0.002     -1.835      0.066      -0.008       0.000
# gold_open:platinum_open                         -6.223e-06   3.89e-06     -1.601      0.109   -1.38e-05    1.39e-06
# silver_open:platinum_open                           0.0010      0.001      1.944      0.052   -8.86e-06       0.002
# gold_open:silver_open:platinum_open             -3.859e-07   2.85e-07     -1.354      0.176   -9.45e-07    1.73e-07
# copper_open:platinum_open                           0.0011      0.001      1.352      0.176      -0.001       0.003
# gold_open:copper_open:platinum_open              1.573e-06   1.25e-06      1.254      0.210   -8.85e-07    4.03e-06
# silver_open:copper_open:platinum_open              -0.0003      0.000     -2.349      0.019      -0.001   -4.87e-05
# gold_open:silver_open:copper_open:platinum_open  1.181e-07   7.06e-08      1.672      0.095   -2.04e-08    2.56e-07
# ===================================================================================================================
# array([[   0, 1108],
#        [   0, 3765]])

# %% [markdown]
# None of the models can predict reliably whether closing prices are going to be higher or lower than the opening prices. But in the previous question we saw that the closing prices are determined pretty accurately by the opening prices. Do the results of this question contradict with the previous question? Can you explain?

# %% [markdown]
# # Question 4
#
# For this question use the following [data](https://archive.ics.uci.edu/ml/datasets/credit+approval):

# %%
credit = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/credit-screening/crx.data', header=None)
X = credit.replace('?',0).iloc[:,[1,2,7,10,14]]
y = credit.iloc[:,15].replace({'+': 1, '-': 0})

# %% [markdown]
# 1. Split the data into training and test set.
# 2. Write different logistic regression models predicting y against X.
# 3. Construct [confusion matrices](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html) on the test data set for these different models.
# 4. Analyze these models. Explain which model is the best model you have found.
# 5. Repeat Steps 1-4 several times. Does your best model stay as the best model? What should be the correct protocol to decide on the best model explaining the data?

# %%
data = pd.DataFrame(X.astype(float))
data.columns = ['a','b','c','d','e']
data['y'] = y
data
# Out:
#          a       b     c    d      e  y
# 0    30.83   0.000  1.25  1.0    0.0  1
# 1    58.67   4.460  3.04  6.0  560.0  1
# 2    24.50   0.500  1.50  0.0  824.0  1
# 3    27.83   1.540  3.75  5.0    3.0  1
# 4    20.17   5.625  1.71  0.0    0.0  1
# ..     ...     ...   ...  ...    ... ..
# 685  21.08  10.085  1.25  0.0    0.0  0
# 686  22.67   0.750  2.00  2.0  394.0  0
# 687  25.25  13.500  2.00  1.0    1.0  0
# 688  17.92   0.205  0.04  0.0  750.0  0
# 689  35.00   3.375  8.29  0.0    0.0  0
#
# [690 rows x 6 columns]

# %%
model = logit('y ~ a + b + c + d',data=data).fit()
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.521267
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  690
# Model:                          Logit   Df Residuals:                      685
# Method:                           MLE   Df Model:                            4
# Date:                Thu, 17 Nov 2022   Pseudo R-squ.:                  0.2413
# Time:                        20:30:09   Log-Likelihood:                -359.67
# converged:                       True   LL-Null:                       -474.08
# Covariance Type:            nonrobust   LLR p-value:                 2.385e-48
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.5940      0.259     -6.152      0.000      -2.102      -1.086
# a              0.0051      0.008      0.653      0.514      -0.010       0.020
# b              0.0390      0.020      1.999      0.046       0.001       0.077
# c              0.1997      0.039      5.157      0.000       0.124       0.276
# d              0.3627      0.043      8.481      0.000       0.279       0.447
# ==============================================================================
# """

# %% [markdown]
# The model can only explain 25% of the variation. This is the simplest model. If we add other interactions, pseudo-R2 does not change significantly. So, we will use this model.

# %%
def experiment(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.75)
    model = LogisticRegression(max_iter=1000)
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    print(confusion_matrix(y_test,y_pred))
    print(model.score(X_test,y_test))

# %%
for i in range(10):
    experiment(X,y)
# Out:
# [[86 12]
#  [29 46]]
# 0.7630057803468208
# [[81 13]
#  [27 52]]
# 0.7687861271676301
# [[85 16]
#  [23 49]]
# 0.7745664739884393
# [[76 11]
#  [37 49]]
# 0.7225433526011561
# [[82  9]
#  [34 48]]
# 0.7514450867052023
# [[83 13]
#  [34 43]]
# 0.7283236994219653
# [[79 10]
#  [35 49]]
# 0.7398843930635838
# [[91  6]
#  [30 46]]
# 0.791907514450867
# [[89 11]
#  [26 47]]
# 0.7861271676300579
# [[84 11]
#  [23 55]]
# 0.8034682080924855
