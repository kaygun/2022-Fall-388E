# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import gzip

from urllib.request import urlopen
from xmltodict import parse
from zipfile import ZipFile
from io import BytesIO

# %% [markdown]
# # Open Data and Data APIs
#
# Large part of doing data science is working with data: cleaning, understanding, filtering, and tranforming it. But in order to do that we need data. Unless you collect your own data, you will need to find interesting data sets that you can understand and ask questions about. Today, we are going to look at possible data sources and their uses.
#
# An [application programming interface (API)](https://en.wikipedia.org/wiki/API) is a data connection between two pieces of software. For our purposes, it is a connection between a data consumer (you) and data provider.  Its primary function is **not** to provide data for human consumption, rather it is for exchanging data between two computer programs. In short, you'll use an API to fetch the data not to look at it in its raw form.

# %% [markdown]
# # Data From Municipalities
#
# There are many cities that provide data about their workings. Here are some city municipalties that serve open data:
#
# 1. [Istanbul Municipality](https://data.ibb.gov.tr/)
# 2. [Izmir Municipality](https://acikveri.bizizmir.com/)
# 3. [Bursa Municipality](https://acikyesil.bursa.bel.tr/dataset/)
# 4. [Athens Open Data](http://geodata.gov.gr/en/dataset)
# 4. [Barcelona Municipality](https://opendata-ajuntament.barcelona.cat/)
# 5. [London Data Store](https://data.london.gov.uk/developers/)
# 6. [New York Open Data](https://opendata.cityofnewyork.us/)
# 7. [City of Montreal Open Data](https://donnees.montreal.ca/collections)
# 8. [City of Toronto Open Data](https://open.toronto.ca/)
#
# Best way to explore is search "open data api" + your favorite city :)
#
#
# Here is the graph of mean natural gas consumption in Istanbul in (numbers are in 10 mil m3) per year

# %%
with urlopen('https://data.ibb.gov.tr/dataset/02bdc2d6-94bb-4e31-816e-528bc9d98703/resource/d5fe41b0-3848-4548-9ac7-6e4756c3027b/download/ilce-baznda-yllara-gore-doalgaz-tuketim-miktar-tr-en.xlsx') as url:
    data = pd.read_excel(url.read())

data
# Out:
#        Yıl  Ay_No         İlçe  Dogalgaz Tüketim Miktarı (m3)
# 0     2015      1       ADALAR                     370333.756
# 1     2015      2       ADALAR                     334257.446
# 2     2015      3       ADALAR                     353314.028
# 3     2015      4       ADALAR                     286268.529
# 4     2015      5       ADALAR                     128612.845
# ...    ...    ...          ...                            ...
# 3193  2021      6  ZEYTİNBURNU                    4813337.694
# 3194  2021      7  ZEYTİNBURNU                    3678340.464
# 3195  2021      8  ZEYTİNBURNU                    4107641.635
# 3196  2021      9  ZEYTİNBURNU                    4569888.391
# 3197  2021     10  ZEYTİNBURNU                    6953389.810
#
# [3198 rows x 4 columns]

# %%
(data.groupby('Yıl')['Dogalgaz Tüketim Miktarı (m3)'].mean()/1e+06).plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Yıl'>

# %% [markdown]
# Here is an example data set from New York about squirrels in the Central Park:

# %%
with urlopen('https://data.cityofnewyork.us/resource/vfnx-vebw.csv') as file:
    squirrel = pd.read_csv(file)
    
squirrel
# Out:
#              x          y unique_squirrel_id hectare shift      date  \
# 0   -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1   -73.968857  40.783783     21B-AM-1019-04     21B    AM  10192018
# 2   -73.974281  40.775534     11B-PM-1014-08     11B    PM  10142018
# 3   -73.959641  40.790313     32E-PM-1017-14     32E    PM  10172018
# 4   -73.970268  40.776213     13E-AM-1017-05     13E    AM  10172018
# ..         ...        ...                ...     ...   ...       ...
# 995 -73.970315  40.778558     16D-AM-1007-01     16D    AM  10072018
# 996 -73.979090  40.768805      3B-AM-1010-10     03B    AM  10102018
# 997 -73.960055  40.791497     33D-AM-1017-03     33D    AM  10172018
# 998 -73.980948  40.768569      2A-PM-1019-04     02A    PM  10192018
# 999 -73.980514  40.769275      2A-AM-1010-08     02A    AM  10102018
#
#      hectare_squirrel_number       age primary_fur_color highlight_fur_color  \
# 0                          3       NaN               NaN                 NaN
# 1                          4       NaN               NaN                 NaN
# 2                          8       NaN              Gray                 NaN
# 3                         14     Adult              Gray                 NaN
# 4                          5     Adult              Gray            Cinnamon
# ..                       ...       ...               ...                 ...
# 995                        1     Adult              Gray               White
# 996                       10     Adult          Cinnamon         Gray, White
# 997                        3     Adult              Gray                 NaN
# 998                        4  Juvenile              Gray               White
# 999                        8     Adult              Gray                 NaN
#
#      ...   kuks  quaas  moans tail_flags tail_twitches  approaches  \
# 0    ...  False  False  False      False         False       False
# 1    ...  False  False  False      False         False       False
# 2    ...  False  False  False      False         False       False
# 3    ...  False  False  False      False         False       False
# 4    ...  False  False  False      False         False       False
# ..   ...    ...    ...    ...        ...           ...         ...
# 995  ...  False  False  False      False         False       False
# 996  ...  False  False  False      False         False       False
# 997  ...  False  False  False      False         False        True
# 998  ...  False  False  False      False         False       False
# 999  ...  False  False  False      False          True       False
#
#      indifferent  runs_from  other_interactions  \
# 0          False      False                 NaN
# 1          False      False                 NaN
# 2          False      False                 NaN
# 3          False       True                 NaN
# 4          False      False                 NaN
# ..           ...        ...                 ...
# 995        False       True                 NaN
# 996         True      False                 NaN
# 997         True      False                 NaN
# 998         True      False                 NaN
# 999        False      False                 NaN
#
#                                 geocoded_column
# 0    POINT (-73.9561344937861 40.7940823884086)
# 1    POINT (-73.9688574691102 40.7837825208444)
# 2    POINT (-73.97428114848522 40.775533619083)
# 3    POINT (-73.9596413903948 40.7903128889029)
# 4    POINT (-73.9702676472613 40.7762126854894)
# ..                                          ...
# 995  POINT (-73.9703149829421 40.7785583630323)
# 996  POINT (-73.9790896775237 40.7688048644871)
# 997  POINT (-73.9600546294497 40.7914969165757)
# 998   POINT (-73.980948293606 40.7685688850628)
# 999   POINT (-73.9805137046778 40.769275143797)
#
# [1000 rows x 31 columns]

# %%
pd.crosstab(squirrel['tail_twitches'],squirrel['indifferent'])
# Out:
# indifferent    False  True
# tail_twitches
# False            454   409
# True              72    65

# %% [markdown]
# # Data from Government Organizations
#
# 1. [European Central Bank](https://sdw.ecb.europa.eu/)
# 2. [OECD data](https://data.oecd.org/)
# 3. [The US Central Bank (FED) data](https://fred.stlouisfed.org/)
# 4. [The World Bank Data](https://data.worldbank.org/)
# 5. [The US Goverment](https://data.gov/developers/apis/index.html) collected all of its open data sources under a single service.
# 6. [Indian Government Data Portal](https://data.gov.in/)
# 7. [European Union Data Portal](https://data.europa.eu/en)
# 8. [Turkish Supreme Election Council](https://acikveri.ysk.gov.tr/anasayfa) (Yüksek Seçim Kurulu) also publishes critical data on all Turkish elections on their data service.
# 9. [International Monetary Fund (IMF) Data Portal](https://www.imf.org/en/Data)

# %%
with urlopen("http://www.ecb.europa.eu/stats/eurofxref/eurofxref-daily.xml") as conn:
    data = parse(conn.read())['gesmes:Envelope']['Cube']['Cube']['Cube']

rates = [ float(x['@rate']) for x in data ]
dates = [ x['@currency'] for x in data ]

df = pd.DataFrame({'rates': rates}, index=dates)
df
# Out:
#           rates
# USD      0.9748
# JPY    141.0100
# BGN      1.9558
# CZK     24.5490
# DKK      7.4365
# GBP      0.8830
# HUF    422.1800
# PLN      4.8483
# RON      4.9490
# SEK     10.8993
# CHF      0.9561
# ISK    140.9000
# NOK     10.5838
# HRK      7.5240
# TRY     18.0841
# AUD      1.5076
# BRL      5.2584
# CAD      1.3401
# CNY      6.9368
# HKD      7.6521
# IDR  14863.2600
# ILS      3.4759
# INR     79.4250
# KRW   1400.6900
# MXN     19.6393
# MYR      4.5201
# NZD      1.7177
# PHP     57.2760
# SGD      1.4001
# THB     36.8230
# ZAR     17.5353

# %%
with urlopen('https://api.worldbank.org/v2/en/indicator/SP.POP.TOTL?downloadformat=xml') as url:
    zfile = ZipFile(BytesIO(url.read()))
    print(zfile.filelist)
    data = parse(zfile.open('API_SP.POP.TOTL_DS2_en_xml_v2_4570889.xml').read())
# Out:
# [<ZipInfo filename='API_SP.POP.TOTL_DS2_en_xml_v2_4570889.xml' compress_type=deflate file_size=4122055 compress_size=161346>]

# %%
[{x['@name']: x['#text'] for x in y['field'] if '#text' in x.keys()} for y in data['Root']['data']['record']]
# Out:
# [{'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1960',
#   'Value': '54208'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1961',
#   'Value': '55434'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1962',
#   'Value': '56234'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1963',
#   'Value': '56699'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1964',
#   'Value': '57029'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1965',
#   'Value': '57357'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1966',
#   'Value': '57702'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1967',
#   'Value': '58044'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1968',
#   'Value': '58377'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1969',
#   'Value': '58734'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1970',
#   'Value': '59070'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1971',
#   'Value': '59442'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1972',
#   'Value': '59849'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1973',
#   'Value': '60236'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1974',
#   'Value': '60527'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1975',
#   'Value': '60653'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1976',
#   'Value': '60586'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1977',
#   'Value': '60366'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1978',
#   'Value': '60102'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1979',
#   'Value': '59972'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1980',
#   'Value': '60097'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1981',
#   'Value': '60561'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1982',
#   'Value': '61341'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1983',
#   'Value': '62213'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1984',
#   'Value': '62826'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1985',
#   'Value': '63024'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1986',
#   'Value': '62645'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1987',
#   'Value': '61838'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1988',
#   'Value': '61072'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1989',
#   'Value': '61033'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1990',
#   'Value': '62152'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1991',
#   'Value': '64623'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1992',
#   'Value': '68240'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1993',
#   'Value': '72495'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1994',
#   'Value': '76705'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1995',
#   'Value': '80324'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1996',
#   'Value': '83211'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1997',
#   'Value': '85450'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1998',
#   'Value': '87280'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '1999',
#   'Value': '89009'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2000',
#   'Value': '90866'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2001',
#   'Value': '92892'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2002',
#   'Value': '94992'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2003',
#   'Value': '97016'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2004',
#   'Value': '98744'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2005',
#   'Value': '100028'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2006',
#   'Value': '100830'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2007',
#   'Value': '101226'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2008',
#   'Value': '101362'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2009',
#   'Value': '101452'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2010',
#   'Value': '101665'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2011',
#   'Value': '102050'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2012',
#   'Value': '102565'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2013',
#   'Value': '103165'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2014',
#   'Value': '103776'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2015',
#   'Value': '104339'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2016',
#   'Value': '104865'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2017',
#   'Value': '105361'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2018',
#   'Value': '105846'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2019',
#   'Value': '106310'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2020',
#   'Value': '106766'},
#  {'Country or Area': 'Aruba',
#   'Item': 'Population, total',
#   'Year': '2021',
#   'Value': '107195'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1960',
#   'Value': '130836765'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1961',
#   'Value': '134159786'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1962',
#   'Value': '137614644'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1963',
#   'Value': '141202036'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1964',
#   'Value': '144920186'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1965',
#   'Value': '148769974'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1966',
#   'Value': '152752671'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1967',
#   'Value': '156876454'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1968',
#   'Value': '161156430'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1969',
#   'Value': '165611760'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1970',
#   'Value': '170257189'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1971',
#   'Value': '175100167'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1972',
#   'Value': '180141148'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1973',
#   'Value': '185376550'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1974',
#   'Value': '190800796'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1975',
#   'Value': '196409937'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1976',
#   'Value': '202205766'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1977',
#   'Value': '208193045'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1978',
#   'Value': '214368393'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1979',
#   'Value': '220740384'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1980',
#   'Value': '227305945'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1981',
#   'Value': '234058404'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1982',
#   'Value': '240999134'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1983',
#   'Value': '248146290'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1984',
#   'Value': '255530063'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1985',
#   'Value': '263161451'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1986',
#   'Value': '271050065'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1987',
#   'Value': '279184536'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1988',
#   'Value': '287524258'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1989',
#   'Value': '296024639'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1990',
#   'Value': '304648010'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1991',
#   'Value': '313394693'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1992',
#   'Value': '322270073'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1993',
#   'Value': '331265579'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1994',
#   'Value': '340379934'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1995',
#   'Value': '349605660'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1996',
#   'Value': '358953595'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1997',
#   'Value': '368440591'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1998',
#   'Value': '378098393'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '1999',
#   'Value': '387977990'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2000',
#   'Value': '398113044'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2001',
#   'Value': '408522129'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2002',
#   'Value': '419223717'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2003',
#   'Value': '430246635'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2004',
#   'Value': '441630149'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2005',
#   'Value': '453404076'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2006',
#   'Value': '465581372'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2007',
#   'Value': '478166911'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2008',
#   'Value': '491173160'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2009',
#   'Value': '504604672'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2010',
#   'Value': '518468229'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2011',
#   'Value': '532760424'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2012',
#   'Value': '547482863'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2013',
#   'Value': '562601578'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2014',
#   'Value': '578075373'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2015',
#   'Value': '593871847'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2016',
#   'Value': '609978946'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2017',
#   'Value': '626392880'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2018',
#   'Value': '643090131'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2019',
#   'Value': '660046272'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2020',
#   'Value': '677243299'},
#  {'Country or Area': 'Africa Eastern and Southern',
#   'Item': 'Population, total',
#   'Year': '2021',
#   'Value': '694665117'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1960',
#   'Value': '8996967'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1961',
#   'Value': '9169406'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1962',
#   'Value': '9351442'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1963',
#   'Value': '9543200'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1964',
#   'Value': '9744772'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1965',
#   'Value': '9956318'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1966',
#   'Value': '10174840'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1967',
#   'Value': '10399936'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1968',
#   'Value': '10637064'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1969',
#   'Value': '10893772'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1970',
#   'Value': '11173654'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1971',
#   'Value': '11475450'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1972',
#   'Value': '11791222'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1973',
#   'Value': '12108963'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1974',
#   'Value': '12412960'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1975',
#   'Value': '12689164'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1976',
#   'Value': '12943093'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1977',
#   'Value': '13171294'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1978',
#   'Value': '13341199'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1979',
#   'Value': '13411060'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1980',
#   'Value': '13356500'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1981',
#   'Value': '13171679'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1982',
#   'Value': '12882518'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1983',
#   'Value': '12537732'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1984',
#   'Value': '12204306'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1985',
#   'Value': '11938204'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1986',
#   'Value': '11736177'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1987',
#   'Value': '11604538'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1988',
#   'Value': '11618008'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1989',
#   'Value': '11868873'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1990',
#   'Value': '12412311'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1991',
#   'Value': '13299016'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1992',
#   'Value': '14485543'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1993',
#   'Value': '15816601'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1994',
#   'Value': '17075728'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1995',
#   'Value': '18110662'},
#  {'Country or Area': 'Afghanistan',
#   'Item': 'Population, total',
#   'Year': '1996',
#   'Value':
},
#  {'Country or Area': 'Azerbaijan',
#   'Item': 'Population, total',
#   'Year': '2017',
#   'Value': '9854033'},
#  {'Country or Area': 'Azerbaijan',
#   'Item': 'Population, total',
#   'Year': '2018',
#   'Value': '9939771'},
#  {'Country or Area': 'Azerbaijan',
#   'Item': 'Population, total',
#   'Year': '2019',
#   'Value': '10024283'},
#  {'Country or Area': 'Azerbaijan',
#   'Item': 'Population, total',
#   'Year': '2020',
#   'Value': '10093121'},
#  {'Country or Area': 'Azerbaijan',
#   'Item': 'Population, total',
#   'Year': '2021',
#   'Value': '10145212'},
#  {'Country or Area': 'Burundi',
#   'Item': 'Population, total',
#   'Year': '1960',
#   'Value': '2797925'},
#  {'Country or Area': 'Burundi',
#   'Item': 'Population, total',
#   'Year': '1961',
#   'Value': '2852438'},
#  {'Country or Area': 'Burundi',
#   'Item': 'Population, total',
#   'Year': '1962',
#   'Value': '2907320'},
#  {'Country or Area': 'Burundi',
#   'Item': 'Population, total',
#   'Year': '1963',
#   'Value': '2964416'},
#  {'Country or Area': 'Burundi',
#   'Item': 'Population, total',
#   'Year': '1964',
#   'Value': '3026292'},
#  {'Country or Area': 'Burundi',
#   'Item': 'Population, total',
#   'Year': '1965',
#   'Value': '3094378'},
#  {'Country or Area': 'Burundi',
#   'Item': 'Population, total',
#   'Year': '1966',
#   'Value': '3170496'},
#  {'Country or Area': 'Burundi',
#   'Item': 'Population, total',
#   'Year': '1967',
#   'Value': '3253215'},
#  ...]

# %% [markdown]
# # Geological Survey and Satellite Image Data
#
# 1. [US Geological Survey (USGS)](https://www.usgs.gov/products) has a very large data store where you can get variety of scientific data that included Earthquakes, Satellite images, Maps, and much much more.
# 2. [European Space Agency](https://open.esa.int/) has an excellent open data service from which you can access a variety of data products such as maps, satellite images and more.
# 3. [NASA](https://data.nasa.gov/) also has an open data service.
# 1. [Grupo de Inteligencia Computacional de la Universidad del País Vasco (UPV/EHU)](http://www.ehu.eus/ccwintco/index.php/Hyperspectral_Remote_Sensing_Scenes) has some standard satellite image datasets that you can experiment with.
# 2. [A large list of open GIS Image data sets](https://freegisdata.rtwilson.com/)

# %% [markdown]
# ### An Example from NASA
#
# ####  Global Landslide Catalog Export
#
# > The Global Landslide Catalog (GLC) was developed with the goal of identifying rainfall-triggered landslide events > around the world, regardless of size, impacts or location. The GLC considers all types of mass movements triggered > by rainfall, which have been reported in the media, disaster databases, scientific reports, or other sources. The > GLC has been compiled since 2007 at NASA Goddard Space Flight Center. This is a unique data set with the ID tag “GLC” in the landslide editor.

# %%
with urlopen('https://data.nasa.gov/api/views/dd9e-wu2v/rows.csv?accessType=DOWNLOAD') as url:
    data = pd.read_csv(url)
    
landslidesTR = data.loc[data['country_code'] == 'TR']
landslidesTR[['event_date','admin_division_name','gazeteer_closest_point','longitude','latitude']]
# Out:
#                   event_date admin_division_name gazeteer_closest_point  \
# 971   09/23/2009 08:00:00 PM              Artvin                 Borçka
# 1155  07/16/2013 08:00:00 AM               Hatay                  Hassa
# 1224  08/24/2015 12:00:00 AM              Artvin                   Hopa
# 2030  09/09/2008 12:00:00 AM               Siirt               Gözpınar
# 2319  07/07/2016 11:00:00 PM             Trabzon                Dağbaşı
# 2608  09/09/2009 12:00:00 AM            Istanbul                Eminönü
# 2700  03/07/2013 12:00:00 AM             Hakkâri                Çukurca
# 2780  11/21/2009 12:00:00 AM             Trabzon                Trabzon
# 2958  01/27/2013 12:00:00 AM          Diyarbakır             Diyarbakır
# 3406  09/28/2008 12:00:00 AM             Sakarya             Karapürçek
# 4199  11/21/2009 12:00:00 AM           Gümüşhane              Yağlıdere
# 4648  09/27/2016 12:00:00 AM            Istanbul             Başakşehir
# 5526  11/12/2015 12:00:00 AM              Artvin                 Borçka
# 6234  08/26/2010 06:00:00 PM                Rize               Gündoğdu
# 6932  07/22/2014 12:00:00 AM             Erzurum                Erzurum
# 7140  07/21/2014 12:00:00 AM               Muğla                   Eşen
# 7211  04/10/2011 09:00:00 AM             Erzurum                Erzurum
# 7540  08/11/2015 12:00:00 AM           Zonguldak                  Kozlu
# 7958  05/28/2007 12:00:00 AM                 Van                    Van
# 8825  08/24/2015 12:00:00 AM              Artvin                   Hopa
# 8897  11/11/2015 12:00:00 AM              Artvin                 Artvin
#
#       longitude  latitude
# 971     41.6822   41.3639
# 1155    36.4354   36.7619
# 1224    41.4323   41.3936
# 2030    41.5061   37.9472
# 2319    39.9081   40.8167
# 2608    28.9759   41.0124
# 2700    43.6143   37.2506
# 2780    39.7365   40.9792
# 2958    40.2306   37.9152
# 3406    30.4580   40.6900
# 4199    39.5272   40.5459
# 4648    28.7701   41.0863
# 5526    41.6800   41.3596
# 6234    40.6167   41.0524
# 6932    41.2522   39.8925
# 7140    29.4080   36.4676
# 7211    41.2679   39.9043
# 7540    31.7365   41.4189
# 7958    43.3948   38.5035
# 8825    41.4709   41.3917
# 8897    41.8196   41.1795

# %% [markdown]
# ### An Example from USGS
#
# Paleohydrologic reconstructions of water-year streamflow for 31 stream gaging sites in the Missouri River Basin with complete data for 1685 through 1977

# %%
with urlopen('https://www.sciencebase.gov/catalog/file/get/5c994278e4b0b8a7f628903e?f=__disk__3d%2F8b%2F51%2F3d8b512c0dec73102f0c8d7b5c3e8d326dce54fa') as url:
    data = pd.read_csv(url)
    
data
# Out:
#      Latitude  Longitude                        Gage or Reconstruction Name  \
# 0   45.116127 -112.75050              Beaverhead River at Barretts, Montana
# 1   45.506912 -112.33089              Ruby River near Twin Bridges, Montana
# 2   45.526581 -112.70172               Big Hole River near Melrose, Montana
# 3   45.897137 -111.59567          Jefferson River near Three Forks, Montana
# 4   45.490231 -111.63451  Madison River below Ennis Lake near McAllister...
# 5   45.823559 -111.49966            Madison River near Three Forks, Montana
# 6   45.885357 -111.43829                   Gallatin River at Logan, Montana
# 7   46.146572 -111.42028                  Missouri River at Toston, Montana
# 8   47.199024 -112.09591                 Dearborn River near Craig, Montana
# 9   47.190052 -111.38719                     Smith River near Eden, Montana
# 10  47.602444 -112.76171      Sun at Gibson Reservoir near Augusta, Montana
# 11  47.525776 -111.51104                     Sun River near Vaughn, Montana
# 12  47.816910 -110.66615              Missouri River at Fort Benton,Montana
# 13  48.305962 -111.08053                 Marias River near Chester, Montanr
# 14  47.930325 -111.55294                  Teton River near Dutton, MontantT
# 15  47.932720 -110.51443                       Teton River at Loma, Montana
# 16  47.668407 -109.65257           Judith River nr mouth, near Winifred, MT
# 17  47.631432 -108.68774              Missouri River near Landusky, Montana
# 18  46.430000 -109.84070            Musselshell River at Harlowton, Montana
# 19  46.994690 -107.88916                Musselshell River at Mosby. Montana
# 20  48.130054 -106.36431                      Milk River at Nashua, Montana
# 21  45.112118 -110.79366       Yellowstone River at Corwin Springs, Montana
# 22  45.009911 -109.06537  Clarks Fork Yellowstone River near Belfry, Mon...
# 23  43.424957 -108.17899        Wind River below BoysenN Reservoir, Wyoming
# 24  44.516621 -109.09792  Shoshone River below Buffalo Bill Reservoir, W...
# 25  45.316902 -107.91889             Bighorn River near St. Xavier, Montana
# 26  46.384594 -105.84552                Tongue River at Miles City, Montana
# 27  46.429436 -105.31033                  Powder River near Locate, Montana
# 28  47.677414 -104.15541             Yellowstone River near Sidney, Montana
# 29  40.936638 -106.33920        North Platte River near Northgate, Colorado
# 30  47.190052 -111.38719       South Platte River at South Platte, Colorado
#
#     USGS Gage ID Year(row) /Id(col)         1685          1686         1687  \
# 0        6016000                 R1   444.433230    363.587220    794.49506
# 1        6023000                 R2   219.264920    141.933170    245.13747
# 2        6025500                 R3  1457.464000   1213.416700   1228.75370
# 3        6036650                 R4  2910.249800   2095.854500   3038.66970
# 4        6041000                 R5  1215.694700   1445.360700   1898.49540
# 5        6042500                 R6  1529.759400   1630.721600   1848.33040
# 6        6052500                 R7  1158.373000   1124.973300   1156.45910
# 7        6054500                 R8  4906.707000   3933.409000   5750.33600
# 8        6073500                 R9   120.766320    188.489850    167.77414
# 9        6077500                R10   296.586060    218.166660    249.01877
# 10       6079500                R11   197.504180    172.072570    437.31793
# 11       6089000                R12   987.806300    875.090100    706.87870
# 12       6090800                R13  6811.506000   4788.586400   9592.53000
# 13       6101500                R14  1255.032100    960.199340    920.59400
# 14       6108000                R15   241.238070    151.473080    190.43983
# 15       6108800                R16   319.520100    238.687640    221.92696
# 16       6114700                R17   150.939010     77.620000     86.81111
# 17       6115200                R18  9944.993000   8042.043000   7229.67330
# 18       6120500                R19   118.598650     41.612810     96.72627
# 19       6130500                R20   587.186650    385.258700    466.20900
# 20       6174500                R21  1521.782500    743.847350   1447.77620
# 21       6191500                R22  2033.032600   1827.309000   2212.02640
# 22       6207500                R23   645.985660    444.321700    617.62180
# 23       6259000                R24   817.489100    878.736400   2568.88870
# 24       6282000                R25   908.357500    836.417240    760.12225
# 25       6287000                R26  4238.896500   4474.296000   5144.15040
# 26       6308500                R27   552.762400   1058.945000    478.16364
# 27       6326500                R28   329.429930    728.032900   1229.60120
# 28       6329500                R29  8893.248000  11576.623000  16314.49200
# 29       6620000                R30    48.725130     72.957620    253.72218
# 30       6707500                R31    16.865316     39.795334    174.67986
#
#            1688         1689  ...         1968         1969         1970  \
# 0     981.97470    658.24810  ...    622.38715    600.00226    572.79840
# 1     380.43802    185.72981  ...    262.86417    316.82214    446.59970
# 2     932.24786   1080.46250  ...   1378.20530   1602.58730   1269.83020
# 3    3656.89580   2312.44870  ...   3400.91630   3679.21660   3243.61080
# 4    1967.13930   1418.36170  ...   1961.48440   2027.46800   1646.18950
# 5    1986.04640   1639.65450  ...   1835.35890   1960.75730   2249.08130
# 6    1501.32980   1279.30940  ...   1519.12220   1522.14400   1686.82680
# 7    5431.72700   5060.82800  ...   6346.73200   7067.96500   6532.60250
# 8     112.52711    235.91763  ...    169.14919    185.14203    207.92440
# 9     546.02515    730.56990  ...    534.23740    535.42110    547.50714
# 10    759.75230    193.72322  ...    893.70400    900.88540    861.45685
# 11    776.54956   1269.36540  ...   1060.67130    856.10040   1085.99850
# 12   8688.62900   9164.87500  ...  10244.87800  10104.25500   9917.28900
# 13    574.40735   1407.85270  ...    925.40283    973.68200   1233.23080
# 14    186.84856    186.79413  ...    209.42973    294.63890    294.29944
# 15    195.66539    257.81995  ...    271.26108    394.53705    331.43057
# 4    1942.11870   1431.26810
# 5    2072.58000   1471.04190
# 6    1755.73390    946.00340
# 7    7175.91600   4608.80570
# 8     281.65634    106.80695
# 9     514.08124    272.23850
# 10   1144.42040    492.86502
# 11   1110.71360    445.49545
# 12  11189.39300   6724.28600
# 13   1287.97630    695.10620
# 14    397.26733    205.42786
# 15    421.59055    307.55225
# 16    239.51619     87.02804
# 17  13911.50600   7547.38530
# 18    326.67184    157.20126
# 19    631.39080    297.30048
# 20    632.71360    192.93433
# 21   3170.67040   2099.91940
# 22   1067.76350    569.12440
# 23   1916.12240   1015.30620
# 24   1446.82370    644.23206
# 25   4964.18850   3114.43020
# 26    514.99976    491.98184
# 27    684.27655    452.02048
# 28  14782.31900  10564.17200
# 29    251.35098    139.29561
# 30    271.88232    172.71964
#
# [31 rows x 298 columns]

# %%
(data.iloc[5,5:]).rolling(window=3).mean().plot(figsize=(20,4))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Image Classification Data Sets
#
# Here is a small sample of image dataset that can be used for image classification tasks:
#
# 1. [MNIST](http://yann.lecun.com/exdb/mnist/)
# 2. [Extended MNIST](https://www.nist.gov/itl/products-and-services/emnist-dataset)
# 3. [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist)
# 4. [Japanese MNIST](https://github.com/rois-codh/kmnist)
# 5. [CIFAR](https://www.cs.toronto.edu/~kriz/cifar.html)
# 6. [Olivetti faces data set](https://scikit-learn.org/0.19/datasets/olivetti_faces.html)

# %%
from sklearn.datasets import fetch_olivetti_faces
from math import sqrt
from random import randint

# %%
olivetti = fetch_olivetti_faces()
olivetti['data'].shape
# Out:
# (400, 4096)

# %%
faces = olivetti['data'].reshape((400,64,64))
N = randint(0,400)
plt.imshow(faces[N])

# %%
with urlopen('http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz') as url:
    fmnist = np.frombuffer(gzip.open(BytesIO(url.read()),'rb').read(), 
                           dtype=np.uint8,
                           offset=16)

fmnist = fmnist.reshape(10000, 784)

# %%
N = np.random.randint(10000)
plt.imshow(fmnist[N].reshape((28,28)))

# %% [markdown]
# # Medical Datasets
#
# 1. [A curated collection of EEG datasets](https://github.com/meagmohit/EEG-Datasets)
# 2. [Physionet](https://physionet.org/about/database/) is an open collection of open human physiological datasets.
# 3. [World Health Organization (WHO)](https://apps.who.int/gho/data/node.resources)
# 4. [Center for Disease Control (CDC)](https://wonder.cdc.gov/DataSets.html)
# 5. [Child Health and Development Studies](https://www.chdstudies.org/research/information_for_researchers.php)
# 6. [National Cancer Institute Datasets](https://seer.cancer.gov/data-software/)
# 7. [Brain/Neural Computer Interaction Datasets](http://bnci-horizon-2020.eu/database/data-sets)

# %% [markdown]
# ## An example with WHO data

# %%
with urlopen('https://covid19.who.int/WHO-COVID-19-global-data.csv') as url:
    data = pd.read_csv(url)
data
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 237469    2022-09-26           ZW     Zimbabwe       AFRO          2
# 237470    2022-09-27           ZW     Zimbabwe       AFRO          0
# 237471    2022-09-28           ZW     Zimbabwe       AFRO          0
# 237472    2022-09-29           ZW     Zimbabwe       AFRO          0
# 237473    2022-09-30           ZW     Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# 1                      0           0                  0
# 2                      0           0                  0
# 3                      0           0                  0
# 4                      0           0                  0
# ...                  ...         ...                ...
# 237469            257342           0               5599
# 237470            257342           0               5599
# 237471            257342           0               5599
# 237472            257342           0               5599
# 237473            257342           0               5599
#
# [237474 rows x 8 columns]

# %%
data[data['Country_code']=='TR']['New_cases'].rolling(window=7).mean().plot()
# Out:
# <AxesSubplot:>

# %%
data[data['Country_code']=='TR']['New_deaths'].rolling(window=7).mean().plot()
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame(data[data['Country_code']=='TR']['New_cases'].fillna(0).rolling(window=10).mean()).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # APIs where you would have to register and login
#
# All of the data sources I quoted above are open. You don't neet to enter credentials to login and access the data. However, most commercial data vendors do ask you to register and login before you access their data.
#
# 1. [NASDAQ Financial Data](https://data.nasdaq.com/). Nasdaq is world's first electronic exchange platform for buying and trading securities. It has an extensive data collection on markets. But you would need their specific python library, and also register at their site (you'll need and API key).
# 2. [Yahoo! Finance Data](https://finance.yahoo.com/quotes/API,Documentation/view/v1/): You can download financial data from Yahoo's financial data API.
# 2. You can fetch data from [twitter](https://twitter.com) through their [API](https://developer.twitter.com/en/docs/twitter-api/getting-started/getting-access-to-the-twitter-api) and analyze it via python libraries. [Tweepy](https://www.tweepy.org/) is a popular choice, but you should definitely look around and find one that suits your needs.

# %% [markdown]
# ## An example from NASDAQ

# %%
import nasdaqdatalink
nasdaqdatalink.read_key("/home/kaygun/.config/apikey")

# %%
data = nasdaqdatalink.get('CHRIS/CME_W1')
data
# Out:
#               Open    High     Low    Last  Change  Settle   Volume  \
# Date
# 1959-07-01  195.70  196.70  195.70  196.40     NaN  196.40   5828.0
# 1959-07-02  196.30  197.40  196.30  197.10     NaN  197.10   4780.0
# 1959-07-06  196.60  197.60  196.60  197.00     NaN  197.00   6591.0
# 1959-07-07  197.30  197.50  196.70  197.10     NaN  197.10   5604.0
# 1959-07-08  197.20  197.40  196.30  196.40     NaN  196.40   4538.0
# ...            ...     ...     ...     ...     ...     ...      ...
# 2021-06-23  653.25  668.25  653.25  662.25   10.25  661.25  35830.0
# 2021-06-24  660.25  660.75  642.00  650.50  -10.00  651.25  27390.0
# 2021-06-25  650.50  656.75  634.50  634.75  -14.25  637.00  35502.0
# 2021-06-28  638.00  655.00  637.00  643.50    9.00  646.00  26862.0
# 2021-06-29  651.00  657.75  638.25  639.50   -6.25  639.75  12053.0
#
#             Previous Day Open Interest
# Date
# 1959-07-01                     25273.0
# 1959-07-02                     26524.0
# 1959-07-06                     27452.0
# 1959-07-07                     28749.0
# 1959-07-08                     30527.0
# ...                                ...
# 2021-06-23                     59819.0
# 2021-06-24                     49474.0
# 2021-06-25                     38808.0
# 2021-06-28                     21189.0
# 2021-06-29                      9821.0
#
# [15617 rows x 8 columns]

# %%
data['Last'].plot(figsize=(18,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
np.log(data['Last']).plot(figsize=(18,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## An example with tweepy

# %%
#!pip install tweepy
import tweepy as tw
import json

# %% [markdown]
# I put all the necessary login details for the api into a single JSON file in my own directory. When you register at twitter you should replace 'apikey' file with your own with the following structure:
#
#     {"API_key": "your api key",
#      "API_secret_key": "your api secret key",
#      "access_token": "your access token",
#      "access_secret": "your access token secret"}

# %%
with open('/home/kaygun/.config/twitter/apikey') as file:
    keys = json.load(file)

# %% [markdown]
# This is how you would login:

# %%
auth = tw.OAuth1UserHandler(
   keys["API_key"], keys["API_secret_key"], keys["access_token"], keys["access_secret"]
)

api = tw.API(auth)

# %% [markdown]
# Let us collect some tweets from this month:

# %%
tweets = api.search_tweets(q='Westworld', lang='en', count=100)

# %% [markdown]
# and display 10 of them:

# %%
[x.text for x in tweets[:10]]
# Out:
# ['28.  Moon knight\n29.  Elite\n30.  Money Heist\n31.  The falcon and the winter soldier\n32.  The Mandalorian \n33.  The… https://t.co/D9efB243fv',
#  "You want to know who I am? Who I really am? I'm a god.",
#  'Westworld now has a provocative Party Host who works in the Import &amp; Export sector at the Kirkby Lonsdale location.… https://t.co/6jIYhSO9Gs',
#  'RT @aberncthy: happy 6th birthday westworld you will always be famous to #real tv enjoyers \U0001faf6 https://t.co/5SES4YKqLE',
#  'Roberto Orci and Alex Kurtzman have broken up but need no introduction.\n\nEdward Kitsis and Adam Horowitz started ou… https://t.co/jhAm543Pzw',
#  'RT @FANdemoniumNet: Join us in wishing a happy birthday to @TessaThompson_x! We hope that you have a wonderful birthday. #happybirthday #te…',
#  '@tanaysriva The extended Westworld soundtrack!',
#  'Westworld Season 1 (Episode 1) - Opening Scenes 1080p https://t.co/q89UoIVip9 via @YouTube',
#  'The company also said that it is committed to the "human form," which immediately evokes scenes from the movie vers… https://t.co/xLCZjxBs9U',
#  "At first, I thought you and the others were Gods. Then I realized you're just men. And I know men."]

# %%
res = api.search_users('Atabey_Kaygun')

# %%
res[0]
# Out:
# User(_api=<tweepy.api.API object at 0x7f337f0d2a10>, _json={'id': 17239073, 'id_str': '17239073', 'name': 'Atabey Kaygun', 'screen_name': 'Atabey_Kaygun', 'location': 'Istanbul', 'description': 'mathematician, batteries included.', 'url': 'https://t.co/T0G1VpGUdq', 'entities': {'url': {'urls': [{'url': 'https://t.co/T0G1VpGUdq', 'expanded_url': 'http://kaygun.tumblr.com/', 'display_url': 'kaygun.tumblr.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1303, 'friends_count': 3561, 'listed_count': 110, 'created_at': 'Fri Nov 07 21:14:10 +0000 2008', 'favourites_count': 6212, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 22009, 'lang': None, 'status': {'created_at': 'Sun Oct 02 08:07:01 +0000 2022', 'id': 1576483881297276928, 'id_str': '1576483881297276928', 'text': 'RT @carlcarrie: 🐙\xa0Generalized additive models in Python with a Bayesian twist - GAMMY\n\nestimate unknown functions from noisy data using spl…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'carlcarrie', 'name': 'Carl Carrie (@🏠)', 'id': 51570722, 'id_str': '51570722', 'indices': [3, 14]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Oct 01 14:49:16 +0000 2022', 'id': 1576222722409246720, 'id_str': '1576222722409246720', 'text': '🐙\xa0Generalized additive models in Python with a Bayesian twist - GAMMY\n\nestimate unknown functions from noisy data u… https://t.co/2DvIdQbd46', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/2DvIdQbd46', 'expanded_url': 'https://twitter.com/i/web/status/1576222722409246720', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': {'id': '085a81a2731ee95a', 'url': 'https://api.twitter.com/1.1/geo/id/085a81a2731ee95a.json', 'place_type': 'city', 'name': 'Manhasset Hills', 'full_name': 'Manhasset Hills, NY', 'country_code': 'US', 'country': 'United States', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-73.694573, 40.751691], [-73.667235, 40.751691], [-73.667235, 40.764239], [-73.694573, 40.764239]]]}, 'attributes': {}}, 'contributors': None, 'is_quote_status': False, 'retweet_count': 15, 'favorite_count': 51, 'favorited': True, 'retweeted': True, 'possibly_sensitive': False, 'lang': 'en'}, 'is_quote_status': False, 'retweet_count': 15, 'favorite_count': 0, 'favorited': True, 'retweeted': True, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1364893530288754689/IE5tGIB8_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1364893530288754689/IE5tGIB8_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17239073/1506154073', 'profile_link_color': '000000', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': Fals ...

# %% [markdown]
# ## An example with Yahoo! Finance

# %%
import yfinance as yf
import numpy as np
import pandas as pd

# %%
msft = yf.Ticker("NDX")
hist = msft.history(period="max")
hist
# Out:
#                     Open          High           Low         Close  \
# Date
# 1985-10-01    110.620003    112.160004    110.565002    112.139999
# 1985-10-02    112.139999    112.540001    110.779999    110.824997
# 1985-10-03    110.839996    111.184998    110.120003    110.870003
# 1985-10-04    110.870003    110.870003    109.855003    110.074997
# 1985-10-07    110.074997    110.135002    108.175003    108.199997
# ...                  ...           ...           ...           ...
# 2022-09-26  11283.139648  11473.360352  11235.740234  11254.110352
# 2022-09-27  11411.339844  11502.379883  11175.290039  11271.750000
# 2022-09-28  11258.740234  11546.870117  11210.809570  11493.830078
# 2022-09-29  11334.570312  11339.910156  11038.940430  11164.780273
# 2022-09-30  11123.110352  11296.160156  10966.950195  10971.219727
#
#                 Volume  Dividends  Stock Splits
# Date
# 1985-10-01   153160000          0           0.0
# 1985-10-02   164640000          0           0.0
# 1985-10-03   147300000          0           0.0
# 1985-10-04   147900000          0           0.0
# 1985-10-07   128640000          0           0.0
# ...                ...        ...           ...
# 2022-09-26  4697730000          0           0.0
# 2022-09-27  4445050000          0           0.0
# 2022-09-28  4556100000          0           0.0
# 2022-09-29  4516630000          0           0.0
# 2022-09-30  4649710000          0           0.0
#
# [9327 rows x 7 columns]

# %%
hist['High'].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
xs = pd.DataFrame(np.log(hist['Close']))
xs.plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## An example with UCI

# %%
with urlopen('https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank.zip') as url:
    zf = ZipFile(BytesIO(url.read()))
    data = pd.read_csv(zf.open('bank.csv'),sep=';')
    
data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %%
res = pd.crosstab(data['education'],data['y'])
res
# Out:
# y            no  yes
# education
# primary     614   64
# secondary  2061  245
# tertiary   1157  193
# unknown     168   19

# %%
xs = res/res.sum(axis=0)
xs
# Out:
# y               no       yes
# education
# primary    0.15350  0.122841
# secondary  0.51525  0.470250
# tertiary   0.28925  0.370441
# unknown    0.04200  0.036468

# %%
import scipy.stats as stats

# %%
stats.ttest_rel(xs['no'],xs['yes'])
# Out:
# Ttest_relResult(statistic=-1.8411330325495386e-16, pvalue=0.9999999999999999)

# %%
res = pd.crosstab(data['default'],data['education'])
res
# Out:
# education  primary  secondary  tertiary  unknown
# default
# no             668       2260      1333      184
# yes             10         46        17        3

# %%
xs = res/res.sum(axis=0)
xs
# Out:
# education   primary  secondary  tertiary   unknown
# default
# no         0.985251   0.980052  0.987407  0.983957
# yes        0.014749   0.019948  0.012593  0.016043

# %%
stats.ttest_rel(xs['unknown'],xs['tertiary'])
# Out:
# Ttest_relResult(statistic=8.04465564198114e-15, pvalue=0.9999999999999949)
